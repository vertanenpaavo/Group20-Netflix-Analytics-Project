# %%
import pandas as pd

# %%
movies = pd.read_csv('DataSets/movies.csv')
movies.head(10)
# Out:
#      movie_id            title     content_type genre_primary genre_secondary  \
# 0  movie_0001    Dragon Legend  Stand-up Comedy       History        Thriller
# 1  movie_0002    Storm Warrior  Stand-up Comedy        Sci-Fi             NaN
# 2  movie_0003      Fire Family            Movie         Drama             NaN
# 3  movie_0004     Our Princess      Documentary        Sci-Fi             NaN
# 4  movie_0005  Warrior Mission      Documentary         Sport         Mystery
# 5  movie_0006  Kingdom Phoenix            Movie   Documentary           Music
# 6  movie_0007     Battle Story        TV Series        Sci-Fi             NaN
# 7  movie_0008        Old House            Movie        Horror             NaN
# 8  movie_0009    Dragon Empire            Movie     Biography             NaN
# 9  movie_0010        Dream War   Limited Series      Thriller       Animation
#
#    release_year  duration_minutes rating  language country_of_origin  \
# ...

# %%
recommendation_logs = pd.read_csv('DataSets/recommendation_logs.csv')
recommendation_logs.head(10)
# Out:
#   recommendation_id     user_id    movie_id recommendation_date  \
# 0        rec_000001  user_06326  movie_0771          2025-07-03
# 1        rec_000002  user_02180  movie_0985          2024-11-07
# 2        rec_000003  user_03535  movie_0834          2024-08-22
# 3        rec_000004  user_05025  movie_0718          2024-04-12
# 4        rec_000005  user_06794  movie_0718          2025-10-30
# 5        rec_000006  user_03345  movie_0346          2024-09-01
# 6        rec_000007  user_01519  movie_0264          2024-06-28
# 7        rec_000008  user_03328  movie_0385          2024-10-09
# 8        rec_000009  user_04944  movie_0957          2025-11-13
# 9        rec_000010  user_07953  movie_0815          2025-02-08
#
#   recommendation_type  recommendation_score  was_clicked  position_in_list  \
# 0        new_releases                   NaN        False                10
# 1         genre_based                 0.916        False                 9
# ...

# %%
reviews = pd.read_csv('DataSets/reviews.csv')
reviews.head(10)
# Out:
#        review_id     user_id    movie_id  rating review_date device_type  \
# 0  review_000001  user_07066  movie_0360       4  2025-03-29      Mobile
# 1  review_000002  user_02953  movie_0095       5  2024-07-19      Mobile
# 2  review_000003  user_05528  movie_0518       4  2025-02-11      Tablet
# 3  review_000004  user_07612  movie_0672       5  2025-11-26      Mobile
# 4  review_000005  user_03424  movie_0580       3  2025-07-11      Mobile
# 5  review_000006  user_07263  movie_0708       3  2025-01-06      Tablet
# 6  review_000007  user_07818  movie_0081       2  2025-01-18    Smart TV
# 7  review_000008  user_03744  movie_0526       1  2025-09-26    Smart TV
# 8  review_000009  user_04454  movie_0551       4  2024-02-02      Mobile
# 9  review_000010  user_02897  movie_0800       3  2025-03-22      Tablet
#
#    is_verified_watch  helpful_votes  total_votes  \
# 0              False            3.0          5.0
# 1               True            2.0          2.0
# ...

# %%
search_logs = pd.read_csv('DataSets/search_logs.csv')
search_logs.head(10)
# Out:
#        search_id     user_id                  search_query search_date  \
# 0  search_000001  user_09864                classic movies  2024-03-22
# 1  search_000002  user_08038               stand up comedy  2025-11-22
# 2  search_000003  user_02009           music documentaries  2024-10-09
# 3  search_000004  user_01083                  comedy shows  2024-12-14
# 4  search_000005  user_04269  movies based on true stories  2025-01-10
# 5  search_000006  user_03478               thriller series  2024-09-18
# 6  search_000007  user_03800          travel documentaries  2025-10-03
# 7  search_000008  user_00191              superhero movies  2024-05-24
# 8  search_000009  user_03999                   biographies  2025-07-18
# 9  search_000010  user_06785  movies based on true stories  2025-04-09
#
#    results_returned  clicked_result_position device_type  \
# 0                20                      2.0      Tablet
# 1                24                      4.0      Tablet
# ...

# %%
users = pd.read_csv('DataSets/users.csv')
users.head(10)
# Out:
#       user_id                        email first_name  last_name   age  \
# 0  user_00001     figueroajohn@example.org      Erica      Garza  43.0
# 1  user_00002        blakeerik@example.com     Joshua    Bernard  38.0
# 2  user_00003          smiller@example.net    Barbara   Williams  32.0
# 3  user_00004    mitchellclark@example.com    Chelsea   Ferguson  11.0
# 4  user_00005        richard13@example.net      Jason     Foster  21.0
# 5  user_00006        jeffrey28@example.com    Katelyn  Hernandez  43.0
# 6  user_00007  maldonadoamanda@example.com     Daniel      Moore  63.0
# 7  user_00008  nathanielmartin@example.net      Carol      Smith   NaN
# 8  user_00009      donnaarroyo@example.org    Allison     Brandt  24.0
# 9  user_00010    morganbrianna@example.org     Adrian      Perez  24.0
#
#    gender country  state_province                city subscription_plan  \
# 0    Male     USA   Massachusetts  North Jefferyhaven             Basic
# ...

# %%
watch_history = pd.read_csv('DataSets/watch_history.csv')
watch_history.head(10)
# Out:
#        session_id     user_id    movie_id  watch_date device_type  \
# 0  session_000001  user_07271  movie_0511  2025-11-13      Tablet
# 1  session_000002  user_00861  movie_0588  2025-02-26      Laptop
# 2  session_000003  user_05391  movie_0694  2024-12-15     Desktop
# 3  session_000004  user_05192  movie_0234  2024-09-30     Desktop
# 4  session_000005  user_05735  movie_0390  2024-08-04      Tablet
# 5  session_000006  user_06266  movie_0631  2024-03-13     Desktop
# 6  session_000007  user_00467  movie_0483  2025-04-23     Desktop
# 7  session_000008  user_04427  movie_0139  2025-09-13      Laptop
# 8  session_000009  user_05579  movie_0769  2025-08-26      Laptop
# 9  session_000010  user_08323  movie_0577  2025-07-23     Desktop
#
#    watch_duration_minutes  progress_percentage     action quality  \
# 0                    63.9                 34.6  completed      HD
# 1                   120.1                 44.2    started      HD
# ...

# %% [markdown]
# TESTING TESTING
